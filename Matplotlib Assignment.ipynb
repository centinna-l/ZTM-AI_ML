# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
plt.plot();

# %%
a = [1,2,3,4,5,6]
plt.plot(a,a);

# %%
x = [1,2,3,4,5]
y = [6,7,8,9,10]
plt.plot(x,y);

# %%
# using object-oriented method.
fig, ax = plt.subplots(figsize=(5,5))
ax.plot(x,y);

# %%
x = [10,20,30,40,50]
y = [2,3,4,5,6]
fig, ax = plt.subplots(figsize = (5,5))
ax.plot(x,y)
ax.set(title="A Random Plot", xlabel="X-Axis", ylabel="Y-Axis")
fig.savefig("random-plot.png");

# %%
import numpy as np

# %%
x = np.linspace(0,10,100)
x
# Out:
# array([ 0.        ,  0.1010101 ,  0.2020202 ,  0.3030303 ,  0.4040404 ,
#         0.50505051,  0.60606061,  0.70707071,  0.80808081,  0.90909091,
#         1.01010101,  1.11111111,  1.21212121,  1.31313131,  1.41414141,
#         1.51515152,  1.61616162,  1.71717172,  1.81818182,  1.91919192,
#         2.02020202,  2.12121212,  2.22222222,  2.32323232,  2.42424242,
#         2.52525253,  2.62626263,  2.72727273,  2.82828283,  2.92929293,
#         3.03030303,  3.13131313,  3.23232323,  3.33333333,  3.43434343,
#         3.53535354,  3.63636364,  3.73737374,  3.83838384,  3.93939394,
#         4.04040404,  4.14141414,  4.24242424,  4.34343434,  4.44444444,
#         4.54545455,  4.64646465,  4.74747475,  4.84848485,  4.94949495,
#         5.05050505,  5.15151515,  5.25252525,  5.35353535,  5.45454545,
#         5.55555556,  5.65656566,  5.75757576,  5.85858586,  5.95959596,
#         6.06060606,  6.16161616,  6.26262626,  6.36363636,  6.46464646,
# ...

# %%
plt.plot(x,x**2);

# %%
plt.scatter(x,np.exp(x));

# %%
plt.scatter(x, np.sin(x));

# %%
favorite_food_prices = {"Pizza":10, "Burger":8, "Ramen":12}

# %%
fig, ax = plt.subplots(figsize=(5,5))
ax.bar(favorite_food_prices.keys(), favorite_food_prices.values())
ax.set(title="Favorite Food", xlabel="Food", ylabel="Prices ($)");

# %%
fig, ax = plt.subplots(figsize = (5,5))
ax.barh(list(favorite_food_prices.keys()), list(favorite_food_prices.values()));

# %%
X = np.random.randn(1000)
fig, ax = plt.subplots(figsize = (5,5))
ax.hist(X);

# %%
X = np.random.random(1000)
fig, ax = plt.subplots(figsize=(5,5))
ax.hist(X);

# %%
fig, ((ax0,ax1),(ax2,ax3)) = plt.subplots(nrows=2, ncols=2, figsize = (10,5))
ax0.plot(X,X/2)
ax1.scatter(np.random.random(10), np.random.random(10))
ax2.bar(list(favorite_food_prices.keys()), list(favorite_food_prices.values()))
ax3.hist(np.random.randn(1000));

# %%
import pandas as pd

# %%
car_sales = pd.read_csv("car-sales.csv")
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
car_sales.dtypes
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
car_sales["Price"] = car_sales["Price"].str.replace("[\\$\\,\\.]","", regex=True)
car_sales["Price"] = car_sales["Price"].str[:-2]

# %%
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4     40
# 1   Honda    Red          87899      4     50
# 2  Toyota   Blue          32549      3     70
# 3     BMW  Black          11179      5    220
# 4  Nissan  White         213095      4     35

# %%
car_sales["Total Sales"] = car_sales["Price"].astype(int).cumsum()
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Total Sales
# 0  Toyota  White         150043      4   4000         4000
# 1   Honda    Red          87899      4   5000         9000
# 2  Toyota   Blue          32549      3   7000        16000
# 3     BMW  Black          11179      5  22000        38000
# 4  Nissan  White         213095      4   3500        41500

# %%
car_sales["Sale Date"] = pd.date_range("13/1/2024", periods=len(car_sales))
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Total Sales  Sale Date
# 0  Toyota  White         150043      4   4000         4000 2024-01-13
# 1   Honda    Red          87899      4   5000         9000 2024-01-14
# 2  Toyota   Blue          32549      3   7000        16000 2024-01-15
# 3     BMW  Black          11179      5  22000        38000 2024-01-16
# 4  Nissan  White         213095      4   3500        41500 2024-01-17

# %%
fig, ax = plt.subplots(figsize = (15,5))
ax.plot(car_sales["Sale Date"], car_sales["Total Sales"]);

# %%
car_sales.plot(x="Sale Date", y="Total Sales");

# %%
car_sales["Price"] = car_sales["Price"].astype(int)

# %%
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Total Sales  Sale Date
# 0  Toyota  White         150043      4   4000         4000 2024-01-13
# 1   Honda    Red          87899      4   5000         9000 2024-01-14
# 2  Toyota   Blue          32549      3   7000        16000 2024-01-15
# 3     BMW  Black          11179      5  22000        38000 2024-01-16
# 4  Nissan  White         213095      4   3500        41500 2024-01-17

# %%
car_sales.plot("Odometer (KM)", "Price", kind="scatter");

# %%
X = np.random.rand(10,4)
df = pd.DataFrame(X, columns=['a','b','c','d'])
df.plot(kind="bar");

# %%
car_sales.plot(x="Make", y="Odometer (KM)", kind="bar");

# %%
car_sales["Odometer (KM)"].plot(kind="hist");

# %%
car_sales["Price"].plot.hist(bins=50);

# %%
heart_disease = pd.read_csv("heart-disease.csv")
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
heart_disease["age"].plot.hist(bins=50);

# %%
heart_disease.plot.hist(figsize = (10,30),subplots=True);

# %%
over_50 = heart_disease[heart_disease["age"] > 50]
len(over_50)
# Out:
# 208
