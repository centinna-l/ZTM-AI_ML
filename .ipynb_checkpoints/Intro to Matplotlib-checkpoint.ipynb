# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
plt.plot();

# %%
plt.plot([1,2,3,4]);

# %%
x = [1,2,3,4]
y = [11,22,33,44]
plt.plot(x,y)

# %%
fig, ax = plt.subplots()
ax.plot(x, [50,100, 220, 330]);

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
# 1. prepare the data
x = [1,2,3,4]
y = [11,22,33,44]

#2. setup plot
fig, ax = plt.subplots(figsize = (10,10))  # (width, height)

#3. Plot the data
ax.plot(x,y)

#4. Customise the plot
ax.set(title="Simple Plot", xlabel="x-axis", ylabel="y-axis")

#5. save the plot
fig.savefig("images/simple-plot.png")

# %% [markdown]
# ### Scatter Plot

# %%
#1. Prepare the data
import numpy as np
import pandas as pd

# %%
x = np.linspace(0,10,100)

fig, ax = plt.subplots()
ax.plot(x,x**2)

# %% [markdown]
# 1. Line Plot
# 2. Scatter Plot
# 3. Bar Plot
# 4. Histogram
# 5. Sub Plot

# %%
# Use same data to make a scatter plot
fig, ax = plt.subplots()
ax.scatter(x, np.exp(x))

# %%
# another scatter plot
fig, ax = plt.subplots()
ax.scatter(x, np.sin(x))
ax.set(title="Another Scatter Plot", xlabel="X Axis", ylabel="Y Axis")
# Out:
# [Text(0.5, 1.0, 'Another Scatter Plot'),
#  Text(0.5, 0, 'X Axis'),
#  Text(0, 0.5, 'Y Axis')]

# %%
# Make a plot from dictionary
nut_butter_prices = {"Almond Butter":10, "Peanut Butter": 8, "Cashew Butter": 12}
fig, ax = plt.subplots()
ax.bar(nut_butter_prices.keys(),nut_butter_prices.values())
ax.set(title="Jerry's Nut Butter Store", ylabel="Prices ($)"); # ; to remove the extra lines and to show the image alone, 
# must be used at the end of the last line.

# %%
fig, ax = plt.subplots()
ax.barh(list(nut_butter_prices.keys()), list(nut_butter_prices.values()));

# %%
# Histograms
x = np.random.randn(1000)
fig, ax = plt.subplots()
ax.hist(x);

# %%
# 2 optiosn for subplots
# Option 1
fig, ((ax1, ax2),(ax3,ax4)) = plt.subplots(nrows=2, ncols=2, figsize=(10,5))
ax1.plot(x,x/2)
ax2.scatter(np.random.random(10), np.random.random(10))
ax3.bar(nut_butter_prices.keys(), nut_butter_prices.values())
ax4.hist(np.random.randn(1000));

# %%
# Option 2
fig, ax = plt.subplots(nrows=2, ncols=2, figsize=(10,5))
ax[0,0].plot(x,x/2)
ax[0,1].scatter(np.random.random(10), np.random.random(10))
ax[1,0].bar(nut_butter_prices.keys(), nut_butter_prices.values())
ax[1,1].hist(np.random.randn(1000));

# %% [markdown]
# ## Plotting data with Pandas

# %%
import pandas as pd

# %%
car_sales = pd.read_csv("car-sales.csv")
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
# start with some dummy data
ts = pd.Series(np.random.randn(1000), index=pd.date_range("1/1/2024", periods=1000))
ts # ts is short for time series
# Out:
# 2024-01-01   -0.555492
# 2024-01-02    1.076191
# 2024-01-03   -0.873175
# 2024-01-04    0.232433
# 2024-01-05   -1.490111
#                 ...
# 2026-09-22    0.824972
# 2026-09-23    2.391818
# 2026-09-24    0.770756
# 2026-09-25    1.508694
# 2026-09-26   -2.810754
# Freq: D, Length: 1000, dtype: float64

# %%
# to add data cumalatively
ts.cumsum()
# Out:
# 2024-01-01    -0.555492
# 2024-01-02     0.520699
# 2024-01-03    -0.352476
# 2024-01-04    -0.120044
# 2024-01-05    -1.610155
#                 ...
# 2026-09-22   -21.513358
# 2026-09-23   -19.121540
# 2026-09-24   -18.350785
# 2026-09-25   -16.842090
# 2026-09-26   -19.652844
# Freq: D, Length: 1000, dtype: float64

# %%
ts.cumsum().plot(kind="line");

# %%
car_sales["Price"] = car_sales["Price"].str.replace('[\\$\\,\\.]','', regex=True)
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
# Remove the last 2 zeros
car_sales["Price"] = car_sales["Price"].str[:-2]
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
# add the date column in the p-df
car_sales["Sale Date"] = pd.date_range("1/1/2024", periods=len(car_sales))
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date
# 0  Toyota  White         150043      4   4000 2024-01-01
# 1   Honda    Red          87899      4   5000 2024-01-02
# 2  Toyota   Blue          32549      3   7000 2024-01-03
# 3     BMW  Black          11179      5  22000 2024-01-04
# 4  Nissan  White         213095      4   3500 2024-01-05
# 5  Toyota  Green          99213      4   4500 2024-01-06
# 6   Honda   Blue          45698      4   7500 2024-01-07
# 7   Honda   Blue          54738      4   7000 2024-01-08
# 8  Toyota  White          60000      4   6250 2024-01-09
# 9  Nissan  White          31600      4   9700 2024-01-10

# %%
# Make total sales column (doesn't work, adds as string)
#car_sales["Total Sales"] = car_sales["Price"].cumsum()

# but the totals sales should be of int data type, not String
car_sales["Total Sales"] = car_sales["Price"].astype(int).cumsum()
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date  Total Sales
# 0  Toyota  White         150043      4   4000 2024-01-01         4000
# 1   Honda    Red          87899      4   5000 2024-01-02         9000
# 2  Toyota   Blue          32549      3   7000 2024-01-03        16000
# 3     BMW  Black          11179      5  22000 2024-01-04        38000
# 4  Nissan  White         213095      4   3500 2024-01-05        41500
# 5  Toyota  Green          99213      4   4500 2024-01-06        46000
# 6   Honda   Blue          45698      4   7500 2024-01-07        53500
# 7   Honda   Blue          54738      4   7000 2024-01-08        60500
# 8  Toyota  White          60000      4   6250 2024-01-09        66750
# 9  Nissan  White          31600      4   9700 2024-01-10        76450

# %%
car_sales.plot(x="Sale Date", y="Total Sales");

# %%
car_sales["Price"] = car_sales["Price"].astype(int)
car_sales.dtypes
# Out:
# Make                     object
# Colour                   object
# Odometer (KM)             int64
# Doors                     int64
# Price                     int64
# Sale Date        datetime64[ns]
# Total Sales               int64
# dtype: object

# %%
car_sales.plot(x="Odometer (KM)", y="Price", kind="scatter");

# %%
x = np.random.rand(10,4)
x
# Out:
# array([[0.02323404, 0.09390198, 0.13223151, 0.74472263],
#        [0.63343069, 0.1349049 , 0.16994841, 0.88535408],
#        [0.33525918, 0.42749869, 0.27620814, 0.49011762],
#        [0.46163442, 0.01465493, 0.61763858, 0.82496377],
#        [0.15637601, 0.6371536 , 0.41171154, 0.65852906],
#        [0.76615252, 0.62374845, 0.8168131 , 0.32842874],
#        [0.84303577, 0.76821608, 0.30201298, 0.65161565],
#        [0.12131595, 0.60044479, 0.30297413, 0.13945096],
#        [0.46773019, 0.70206775, 0.68160365, 0.67008808],
#        [0.82619364, 0.76628548, 0.86701745, 0.92651371]])

# %%
# Turn the data into a dataframe.
df = pd.DataFrame(x, columns=['a', 'b', 'c', 'd'])
df
# Out:
#           a         b         c         d
# 0  0.023234  0.093902  0.132232  0.744723
# 1  0.633431  0.134905  0.169948  0.885354
# 2  0.335259  0.427499  0.276208  0.490118
# 3  0.461634  0.014655  0.617639  0.824964
# 4  0.156376  0.637154  0.411712  0.658529
# 5  0.766153  0.623748  0.816813  0.328429
# 6  0.843036  0.768216  0.302013  0.651616
# 7  0.121316  0.600445  0.302974  0.139451
# 8  0.467730  0.702068  0.681604  0.670088
# 9  0.826194  0.766285  0.867017  0.926514

# %%
df.plot(kind="bar");

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date  Total Sales
# 0  Toyota  White         150043      4   4000 2024-01-01         4000
# 1   Honda    Red          87899      4   5000 2024-01-02         9000
# 2  Toyota   Blue          32549      3   7000 2024-01-03        16000
# 3     BMW  Black          11179      5  22000 2024-01-04        38000
# 4  Nissan  White         213095      4   3500 2024-01-05        41500
# 5  Toyota  Green          99213      4   4500 2024-01-06        46000
# 6   Honda   Blue          45698      4   7500 2024-01-07        53500
# 7   Honda   Blue          54738      4   7000 2024-01-08        60500
# 8  Toyota  White          60000      4   6250 2024-01-09        66750
# 9  Nissan  White          31600      4   9700 2024-01-10        76450

# %%
car_sales.plot(x="Make", y="Odometer (KM)", kind="bar");

# %%
# Histograms
car_sales["Odometer (KM)"].plot(kind="hist");

# %%
car_sales["Odometer (KM)"].plot.hist(bins=10);

# %%
# Import Heart Disease
heart_disease = pd.read_csv("heart-disease.csv")
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
# create a histogram of the age column.
heart_disease["age"].plot(kind="hist", bins=50);

# %%
heart_disease.dtypes
# Out:
# age           int64
# sex           int64
# cp            int64
# trestbps      int64
# chol          int64
# fbs           int64
# restecg       int64
# thalach       int64
# exang         int64
# oldpeak     float64
# slope         int64
# ca            int64
# thal          int64
# target        int64
# dtype: object

# %%
heart_disease.plot(kind="hist", figsize=(5,20), subplots=True);

# %%
over_50 = heart_disease[heart_disease["age"] > 50]
over_50
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# 5     57    1   0       140   192    0        1      148      0      0.4
# 6     56    0   1       140   294    0        0      153      0      1.3
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 297   59    1   0       164   176    1        0       90      0      1.0
# 298   57    0   0       140   241    0        1      123      1      0.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 3        2   0     2       1
# 4        2   0     2       1
# 5        1   0     1       1
# 6        1   0     2       1
# ..     ...  ..   ...     ...
# 297      1   2     1       0
# 298      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0
#
# [208 rows x 14 columns]

# %%
over_50.plot(kind="scatter",
             x="age",
             y="chol",
             c="target", # gives black/white color, 0/1 for the target value.
             figsize=(10,6));

# %%
# Method 2
fig, ax = plt.subplots(figsize=(10,6))
over_50.plot(kind="scatter", x="age", y="chol",c="target",ax=ax)
ax.set_xlim([45,100]);
